# %% [markdown]
# Number Guessing Game:
#
# The Goal: The program randomly selects a number between 1 and 100. The user guesses the number, and the program replies with "Too high!", "Too low!", or "You got it!". The game loops until the user guesses correctly.
#
# Concepts Tested: while loops, if/elif/else statements, comparison operators, importing the basic random module.

# %%
import random
print("Welcome to Number Guessing Game!")
# Random number between 1 and 100
secret_number = random.randint(1, 100)

# Initialize guess variable
guess = 0

# Game loop
while guess != secret_number:
    guess = int(input("Guess a number between 1 and 100: "))

    if guess > secret_number:
        print("Too high! Try again.")
    elif guess < secret_number:
        print("Too low! Try again.")
    else:
        print("🎉 You got it! Congratulations!")
# Out:
# Welcome to Number Guessing Game!
# Guess a number between 1 and 100:  1
# Too low! Try again.
# Guess a number between 1 and 100:  39
# Too high! Try again.
# Guess a number between 1 and 100:  100
# Too high! Try again.
# Guess a number between 1 and 100:  56
# Too high! Try again.
# Guess a number between 1 and 100:  34
# Too high! Try again.
# Guess a number between 1 and 100:  23
# Too low! Try again.
# Guess a number between 1 and 100:  57
# Too high! Try again.
# Guess a number between 1 and 100:  34
# Too high! Try again.
# Guess a number between 1 and 100:  20
# Too low! Try again.
# Guess a number between 1 and 100:  25
# Too low! Try again.
# Guess a number between 1 and 100:  30
# Too high! Try again.
# Guess a number between 1 and 100:  29
# Too high! Try again.
# Guess a number between 1 and 100:  28
# 🎉 You got it! Congratulations!

# %% [markdown]
# Rock, Paper, Scissors:
#
# The Goal: A continuous loop where the user plays Rock, Paper, Scissors against the computer. Keep track of the score until the user types "quit".
#
# Concepts Tested: Infinite loops with break conditions, complex if/elif logic, string normalization (e.g., using .lower()).

# %%
import random

# Score variables
user_score = 0
computer_score = 0

choices = ["rock", "paper", "scissors"]

while True:
    user = input("Enter rock, paper, scissors or quit: ").lower()

    if user == "quit":
        print("Game Over!")
        print("Final Score -> You:", user_score, "Computer:", computer_score)
        break

    if user not in choices:
        print("Invalid choice. Try again.")
        continue

    computer = random.choice(choices)

    print("You chose:", user)
    print("Computer chose:", computer)

    if user == computer:
        print("It's a tie!")

    elif (user == "rock" and computer == "scissors") or \
         (user == "scissors" and computer == "paper") or \
         (user == "paper" and computer == "rock"):
        print("You win!")
        user_score += 1

    else:q
        print("Computer wins!")
        computer_score += 1

    print("Score -> You:", user_score, "| Computer:", computer_score)
    print("----------------------")
# Out:
# Enter rock, paper, scissors or quit:  rock
# You chose: rock
# Computer chose: paper
# Computer wins!
# Score -> You: 0 | Computer: 1
# ----------------------
# Enter rock, paper, scissors or quit:  paper
# You chose: paper
# Computer chose: rock
# You win!
# Score -> You: 1 | Computer: 1
# ----------------------
# Enter rock, paper, scissors or quit:  scissors
# You chose: scissors
# Computer chose: rock
# Computer wins!
# Score -> You: 1 | Computer: 2
# ----------------------
# Enter rock, paper, scissors or quit:  rock
# You chose: rock
# Computer chose: scissors
# You win!
# Score -> You: 2 | Computer: 2
# ----------------------
# Enter rock, paper, scissors or quit:  scissors
# You chose: scissors
# Computer chose: paper
# You win!
# Score -> You: 3 | Computer: 2
# ----------------------
# Enter rock, paper, scissors or quit:  paper
# You chose: paper
# Computer chose: rock
# You win!
# Score -> You: 4 | Computer: 2
# ----------------------
# Enter rock, paper, scissors or quit:  rock
# You chose: rock
# Computer chose: rock
# It's a tie!
# Score -> You: 4 | Computer: 2
# ----------------------
# Enter rock, paper, scissors or quit:  rock
# You chose: rock
# Computer chose: scissors
# You win!
# Score -> You: 5 | Computer: 2
# ----------------------
# Enter rock, paper, scissors or quit:  scissors
# You chose: scissors
# Computer chose: scissors
# It's a tie!
# Score -> You: 5 | Computer: 2
# ----------------------
# Enter rock, paper, scissors or quit:  scissors
# You chose: scissors
# Computer chose: scissors
# It's a tie!
# Score -> You: 5 | Computer: 2
# ----------------------
# Enter rock, paper, scissors or quit:  scissors
# You chose: scissors
# Computer chose: paper
# You win!
# Score -> You: 6 | Computer: 2
# ----------------------
# Enter rock, paper, scissors or quit:  paper
# You chose: paper
# Computer chose: paper
# It's a tie!
# Score -> You: 6 | Computer: 2
# ----------------------
# Enter rock, paper, scissors or quit:  paper
# You chose: paper
# Computer chose: scissors
# Computer wins!
# Score -> You: 6 | Computer: 3
# ----------------------
# Enter rock, paper, scissors or quit:  paper
# You chose: paper
# Computer chose: scissors
# Computer wins!
# Score -> You: 6 | Computer: 4
# ----------------------
# Enter rock, paper, scissors or quit:  scissor
# Invalid choice. Try again.
# Enter rock, paper, scissors or quit:  scissors
# You chose: scissors
# Computer chose: scissors
# It's a tie!
# Score -> You: 6 | Computer: 4
# ----------------------
# Enter rock, paper, scissors or quit:  scissors
# You chose: scissors
# Computer chose: paper
# You win!
# Score -> You: 7 | Computer: 4
# ----------------------
# Enter rock, paper, scissors or quit:  paper
# You chose: paper
# Computer chose: paper
# It's a tie!
# Score -> You: 7 | Computer: 4
# ----------------------
# Enter rock, paper, scissors or quit:  paper
# You chose: paper
# Computer chose: rock
# You win!
# Score -> You: 8 | Computer: 4
# ----------------------
# Enter rock, paper, scissors or quit:  quit
# Game Over!
# Final Score -> You: 8 Computer: 4

# %% [markdown]
# The Virtual Barista (Simple Point-of-Sale)
#
# The Goal: Display a text menu of three coffee shop drinks with different prices. Create a continuous loop that asks the user what they want to order. Add the price of their chosen drink to a running total. If they type an invalid drink, tell them it's not on the menu. The loop should continue until the user types "checkout", at which point the program prints their final total.
#
# Concepts Tested: Infinite while loops, break conditions, accumulating totals (+= operator), complex if/elif/else logic, and string normalization (using .lower() to handle if the user types "Checkout" or "CHECKOUT").

# %%
print("Welcome to chii mom coffee shop!")

print("Menu:")
print("Matcha latte - $4")
print("Coffee - $3")
print("Ice Tea - $2")

total = 0

while True:
    customer = input("What would you like to order? (type checkout to finish): ").lower()

    if customer == "checkout":
        print("Your final total is: $", total)
        break

    elif customer == "matcha latte":
        total += 4
        print("Matcha latte added!")

    elif customer == "coffee":
        total += 3
        print("Coffee added!")

    elif customer == "ice tea":
        total += 2
        print("Ice Tea added!")

    else:
        print("Sorry, that drink is not on the menu.")

    print("Current total: $", total)
# Out:
# Welcome to chii mom coffee shop!
# Menu:
# Matcha latte - $4
# Coffee - $3
# Ice Tea - $2
# What would you like to order? (type checkout to finish):  Coffee
# Coffee added!
# Current total: $ 3
# What would you like to order? (type checkout to finish):  checkout
# Your final total is: $ 3

# %% [markdown]
# The Mental Math Challenger
#
# The Goal: The program generates two random numbers between 1 and 12 and asks the user to multiply them together (e.g., "What is 7 x 8?"). If the user gets it right, they get a point, and the program asks another question. If they get it wrong, the program tells them the correct answer and ends the game, displaying their final streak/score.
#
# Concepts Tested: Importing the random module, tracking score variables, while loops dependent on a boolean condition (e.g., while is_correct:), if/else statements, and type casting (converting the user's answer to an int to compare it to the actual math result).

# %%
import random

print("Welcome to the Mental Math Challenger!")

score = 0
is_correct = True

while is_correct:
    num1 = random.randint(1, 12)
    num2 = random.randint(1, 12)

    answer = int(input(f"What is {num1} x {num2}? "))

    correct_answer = num1 * num2

    if answer == correct_answer:
        score += 1
        print("Correct! Your score:", score)
    else:
        print("Wrong!")
        print("The correct answer is:", correct_answer)
        is_correct = False

print("Game Over! Your final score is:", score)
# Out:
# Welcome to the Mental Math Challenger!
# What is 6 x 12?  72
# Correct! Your score: 1
# What is 7 x 9?  63
# Correct! Your score: 2
# What is 7 x 5?  35
# Correct! Your score: 3
# What is 1 x 4?  4
# Correct! Your score: 4
# What is 9 x 4?  36
# Correct! Your score: 5
# What is 10 x 1?  10
# Correct! Your score: 6
